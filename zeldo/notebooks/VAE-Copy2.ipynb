# %%
# Activate TF2 behavior:
from tensorflow.python import tf2
if not tf2.enabled():
  import tensorflow.compat.v2 as tf
  tf.enable_v2_behavior()
  assert tf2.enabled()


import numpy as np
import tensorflow as tf

# Set seeds
np.random.seed(10)
tf.random.set_seed(10)

from tensorflow.keras.layers import Input, Dense, LSTM, Lambda, Dropout, Flatten, Reshape, Conv2DTranspose
from tensorflow.keras.layers import Conv2D, UpSampling2D, MaxPooling2D

from tensorflow.keras import optimizers, models, regularizers
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.models import load_model, Sequential, Model
from tensorflow.keras.regularizers import l1
from tensorflow.keras.utils import plot_model
from keras.losses import mse, binary_crossentropy

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, MinMaxScaler

import matplotlib.pyplot as plt

mode = 'train'
# Out:
# Using TensorFlow backend.

# %%
num_epochs = 300 #5000
batch_size = 256
learning_rate = 3e-5 #1e-4
decay_rate = 1e-3 # 1e-1

latent_dim = 2*2*2
epsilon_mean = 1.0
epsilon_std = 1e-3

# %%
output = np.load("/Users/dongxiaofeng/Documents/GitHub/zeldo/Zeldotest.np.npy")
output = (output - output.min() )/(output.max() - output.min())

swe_train = output[0:800,:,:]
swe_valid = output[800:1000,:,:]

swe_train = swe_train.reshape(800,64,64,1)
swe_valid = swe_valid.reshape(200,64,64,1)

# # Visualize transformations
# plt.figure()
# plt.imshow(swe_train[0].reshape(64,64))
# plt.show()

# plt.figure()
# plt.imshow(swe_train[1].reshape(64,64))
# plt.show()

# plt.figure()
# plt.imshow(swe_train[2].reshape(64,64))
# plt.show()
# exit()

# Shuffle
swe_train_data = np.copy(swe_train)
swe_valid_data = np.copy(swe_valid)

np.random.shuffle(swe_train_data)
np.random.shuffle(swe_valid_data)


def coeff_determination(y_pred, y_true): #Order of function inputs is important here        
    SS_res =  K.sum(K.square( y_true-y_pred )) 
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) )
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %%
print(swe_valid.shape)
# Out:
# (200, 64, 64, 1)

# %%
# reparameterization trick
# instead of sampling from Q(z|X), sample eps = N(0,I)
# then z = z_mean + sqrt(var)*eps
def sampling(args):
    """Reparameterization trick by sampling fr an isotropic unit Gaussian.
     Arguments
        args (tensor): mean and log of variance of Q(z|X)
     Returns
        z (tensor): sampled latent vector
    """

    z_mean, z_log_var = args
    batch = K.shape(z_mean)[0]
    dim = K.int_shape(z_mean)[1]
    # by default, random_normal has mean=0 and std=1.0
    epsilon = K.random_normal(shape=(batch, dim), mean=epsilon_mean, stddev=epsilon_std)
    return z_mean + K.exp(0.5 * z_log_var) * epsilon

# %%
## Encoder
    
encoder_inputs = Input(shape=(64,64,1),name='Field')
# Encode   
x = Conv2D(30,kernel_size=(3,3),activation='relu',padding='same')(encoder_inputs)

x = Conv2D(30,kernel_size=(3,3),activation='relu',padding='same')(x)

enc_l2 = MaxPooling2D(pool_size=(2, 2),padding='same')(x)

x = Conv2D(25,kernel_size=(3,3),activation='relu',padding='same')(enc_l2)
enc_l3 = MaxPooling2D(pool_size=(2, 2),padding='same')(x)

x = Conv2D(20,kernel_size=(3,3),activation='relu',padding='same')(enc_l3)
enc_l4 = MaxPooling2D(pool_size=(2, 2),padding='same')(x)

x = Conv2D(15,kernel_size=(3,3),activation='relu',padding='same')(enc_l4)
enc_l5 = MaxPooling2D(pool_size=(2, 2),padding='same')(x)

x = Conv2D(2,kernel_size=(3,3),activation=None,padding='same')(enc_l5)
encoded = MaxPooling2D(pool_size=(2, 2),padding='same')(x)

x = Flatten()(x)
#x = Dense(32, activation='linear')(x)
x = Dense(16, activation='linear')(x)

z_mean = Dense(latent_dim, name='z_mean')(x)
z_log_var = Dense(latent_dim, name='z_log_var')(x)

# use reparameterization trick to push the sampling out as input
# note that "output_shape" isn't necessary with the TensorFlow backend
z = Lambda(sampling, output_shape=(latent_dim,), name='z')([z_mean, z_log_var])

# instantiate encoder model
encoder = Model(encoder_inputs, [z_mean, z_log_var, z], name='encoder')
encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Field (InputLayer)              [(None, 64, 64, 1)]  0
# __________________________________________________________________________________________________
# conv2d_148 (Conv2D)             (None, 64, 64, 30)   300         Field[0][0]
# __________________________________________________________________________________________________
# conv2d_149 (Conv2D)             (None, 64, 64, 30)   8130        conv2d_148[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_60 (MaxPooling2D) (None, 32, 32, 30)   0           conv2d_149[0][0]
# __________________________________________________________________________________________________
# conv2d_150 (Conv2D)             (None, 32, 32, 25)   6775        max_pooling2d_60[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_61 (MaxPooling2D) (None, 16, 16, 25)   0           conv2d_150[0][0]
# __________________________________________________________________________________________________
# conv2d_151 (Conv2D)             (None, 16, 16, 20)   4520        max_pooling2d_61[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_62 (MaxPooling2D) (None, 8, 8, 20)     0           conv2d_151[0][0]
# __________________________________________________________________________________________________
# conv2d_152 (Conv2D)             (None, 8, 8, 15)     2715        max_pooling2d_62[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_63 (MaxPooling2D) (None, 4, 4, 15)     0           conv2d_152[0][0]
# __________________________________________________________________________________________________
# conv2d_153 (Conv2D)             (None, 4, 4, 2)      272         max_pooling2d_63[0][0]
# __________________________________________________________________________________________________
# flatten_12 (Flatten)            (None, 32)           0           conv2d_153[0][0]
# __________________________________________________________________________________________________
# dense_24 (Dense)                (None, 16)           528         flatten_12[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 8)            136         dense_24[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 8)            136         dense_24[0][0]
# __________________________________________________________________________________________________
# z (Lambda)                      (None, 8)            0           z_mean[0][0]
#                                                                  z_log_var[0][0]
# ==================================================================================================
# Total params: 23,512
# Trainable params: 23,512
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# build decoder model
latent_inputs = Input(shape=(latent_dim,), name='z_sampling')
#x = Dense(16, activation='linear')(latent_inputs)
#x = Dense(32, activation='linear')(x)
x = Dense(2*2*2, activation='linear')(latent_inputs)
x = Reshape((2, 2, 2))(x)

# decoder_inputs = Input(shape=(2,2,2),name='decoded')
    
x = Conv2D(2,kernel_size=(3,3),activation=None,padding='same')(x)
dec_l1 = UpSampling2D(size=(2, 2))(x)

x = Conv2D(15,kernel_size=(3,3),activation='relu',padding='same')(dec_l1)
dec_l2 = UpSampling2D(size=(2, 2))(x)

x = Conv2D(20,kernel_size=(3,3),activation='relu',padding='same')(dec_l2)
dec_l3 = UpSampling2D(size=(2, 2))(x)

x = Conv2D(25,kernel_size=(3,3),activation='relu',padding='same')(dec_l3)
dec_l4 = UpSampling2D(size=(2, 2))(x)

x = Conv2D(30,kernel_size=(3,3),activation='relu',padding='same')(dec_l4)
dec_l5 = UpSampling2D(size=(2, 2))(x)

x = Conv2D(30,kernel_size=(3,3),activation='relu',padding='same')(x)




decoded = Conv2D(1,kernel_size=(3,3),activation=None,padding='same')(dec_l5)
decoder = Model(inputs=latent_inputs,outputs=decoded)

# decoder = Model(latent_inputs, outputs, name='decoder')
decoder.summary()
plot_model(decoder, to_file='vae_cnn_decoder.png', show_shapes=True)

# instantiate VAE model
#outputs = decoder(encoder(encoder_inputs))
# vae = Model(encoder_inputs, outputs, name='vae')

plot_model(decoder, to_file='vae_cnn_decoder.png', show_shapes=True)
# Out:
# Model: "model_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# z_sampling (InputLayer)      [(None, 8)]               0
# _________________________________________________________________
# dense_25 (Dense)             (None, 8)                 72
# _________________________________________________________________
# reshape_12 (Reshape)         (None, 2, 2, 2)           0
# _________________________________________________________________
# conv2d_154 (Conv2D)          (None, 2, 2, 2)           38
# _________________________________________________________________
# up_sampling2d_60 (UpSampling (None, 4, 4, 2)           0
# _________________________________________________________________
# conv2d_155 (Conv2D)          (None, 4, 4, 15)          285
# _________________________________________________________________
# up_sampling2d_61 (UpSampling (None, 8, 8, 15)          0
# _________________________________________________________________
# conv2d_156 (Conv2D)          (None, 8, 8, 20)          2720
# _________________________________________________________________
# up_sampling2d_62 (UpSampling (None, 16, 16, 20)        0
# _________________________________________________________________
# conv2d_157 (Conv2D)          (None, 16, 16, 25)        4525
# _________________________________________________________________
# up_sampling2d_63 (UpSampling (None, 32, 32, 25)        0
# _________________________________________________________________
# conv2d_158 (Conv2D)          (None, 32, 32, 30)        6780
# _________________________________________________________________
# up_sampling2d_64 (UpSampling (None, 64, 64, 30)        0
# _________________________________________________________________
# conv2d_160 (Conv2D)          (None, 64, 64, 1)         271
# =================================================================
# Total params: 14,691
# Trainable params: 14,691
# Non-trainable params: 0
# _________________________________________________________________
# Failed to import pydot. You must install pydot and graphviz for `pydotprint` to work.
# Failed to import pydot. You must install pydot and graphviz for `pydotprint` to work.

# %%
## Autoencoder

# instantiate VAE model
# ae_outputs = decoder(encoder(inputs)[2])
ae_outputs = decoder(encoder(encoder_inputs)) 
model = Model(encoder_inputs, ae_outputs, name='vae')

# %%
# !pip install pydot
# !pip install graphviz

import pydot
# Out:
# Requirement already satisfied: pydot in /Users/dongxiaofeng/anaconda3/lib/python3.7/site-packages (1.4.1)
# Requirement already satisfied: pyparsing>=2.1.4 in /Users/dongxiaofeng/anaconda3/lib/python3.7/site-packages (from pydot) (2.3.1)
# Requirement already satisfied: graphviz in /Users/dongxiaofeng/anaconda3/lib/python3.7/site-packages (0.14)

# %%
import pydot

# %%
# reconstruction_loss = binary_crossentropy(K.flatten(encoder_inputs), K.flatten(ae_outputs))
reconstruction_loss = mse(K.flatten(encoder_inputs), K.flatten(ae_outputs))

kl_loss = 1 + z_log_var - K.square(z_mean) - K.exp(z_log_var)
kl_loss = K.sum(kl_loss, axis=-1)
kl_loss *= -0.5
vae_loss = K.mean(reconstruction_loss + kl_loss)
model.add_loss(vae_loss)
model.compile(optimizer='adam')
K.set_value(model.optimizer.lr, learning_rate)
K.set_value(model.optimizer.decay, decay_rate)
model.summary()
plot_model(model, to_file='vae_cnn.png', show_shapes=True)
# Out:
# Model: "vae"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Field (InputLayer)              [(None, 64, 64, 1)]  0
# __________________________________________________________________________________________________
# encoder (Model)                 [(None, 8), (None, 8 23512       Field[0][0]
# __________________________________________________________________________________________________
# model_12 (Model)                (None, 64, 64, 1)    14691       encoder[1][0]
#                                                                  encoder[1][1]
#                                                                  encoder[1][2]
# __________________________________________________________________________________________________
# conv2d_148 (Conv2D)             (None, 64, 64, 30)   300         Field[0][0]
# __________________________________________________________________________________________________
# conv2d_149 (Conv2D)             (None, 64, 64, 30)   8130        conv2d_148[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_60 (MaxPooling2D) (None, 32, 32, 30)   0           conv2d_149[0][0]
# __________________________________________________________________________________________________
# conv2d_150 (Conv2D)             (None, 32, 32, 25)   6775        max_pooling2d_60[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_61 (MaxPooling2D) (None, 16, 16, 25)   0           conv2d_150[0][0]
# __________________________________________________________________________________________________
# conv2d_151 (Conv2D)             (None, 16, 16, 20)   4520        max_pooling2d_61[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_62 (MaxPooling2D) (None, 8, 8, 20)     0           conv2d_151[0][0]
# __________________________________________________________________________________________________
# conv2d_152 (Conv2D)             (None, 8, 8, 15)     2715        max_pooling2d_62[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_63 (MaxPooling2D) (None, 4, 4, 15)     0           conv2d_152[0][0]
# __________________________________________________________________________________________________
# conv2d_153 (Conv2D)             (None, 4, 4, 2)      272         max_pooling2d_63[0][0]
# __________________________________________________________________________________________________
# flatten_12 (Flatten)            (None, 32)           0           conv2d_153[0][0]
# __________________________________________________________________________________________________
# dense_24 (Dense)                (None, 16)           528         flatten_12[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 8)            136         dense_24[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 8)            136         dense_24[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_22 (TensorFlo [(None, 8)]          0           z_log_var[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Square_23 (TensorFl [(None, 8)]          0           z_mean[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_24 (TensorF [(None,)]            0           model_12[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_23 (TensorF [(None,)]            0           Field[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_34 (TensorFlowO [(None, 8)]          0           tf_op_layer_AddV2_22[0][0]
#                                                                  tf_op_layer_Square_23[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Exp_11 (TensorFlowO [(None, 8)]          0           z_log_var[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_33 (TensorFlowO [(None,)]            0           tf_op_layer_Reshape_24[0][0]
#                                                                  tf_op_layer_Reshape_23[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_35 (TensorFlowO [(None, 8)]          0           tf_op_layer_Sub_34[0][0]
#                                                                  tf_op_layer_Exp_11[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Square_22 (TensorFl [(None,)]            0           tf_op_layer_Sub_33[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum_11 (TensorFlowO [(None,)]            0           tf_op_layer_Sub_35[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mean_22 (TensorFlow [()]                 0           tf_op_layer_Square_22[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_11 (TensorFlowO [(None,)]            0           tf_op_layer_Sum_11[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_23 (TensorFlo [(None,)]            0           tf_op_layer_Mean_22[0][0]
#                                                                  tf_op_layer_Mul_11[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mean_23 (TensorFlow [()]                 0           tf_op_layer_AddV2_23[0][0]
# __________________________________________________________________________________________________
# add_loss_11 (AddLoss)           ()                   0           tf_op_layer_Mean_23[0][0]
# ==================================================================================================
# Total params: 38,203
# Trainable params: 38,203
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Failed to import pydot. You must install pydot and graphviz for `pydotprint` to work.

# %%
if mode == 'train':
    # train the autoencoder
    hist = model.fit(swe_train_data, epochs=num_epochs, batch_size=batch_size, validation_split=0.1)
    model.save_weights('vae_cnn')
# Out:
# Epoch 1/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0046 - val_loss: 0.0044
# Epoch 2/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0044 - val_loss: 0.0043
# Epoch 3/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0043 - val_loss: 0.0042
# Epoch 4/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0043 - val_loss: 0.0042
# Epoch 5/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0042 - val_loss: 0.0041
# Epoch 6/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 7/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0041 - val_loss: 0.0040
# Epoch 8/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 9/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0040 - val_loss: 0.0039
# Epoch 10/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0039 - val_loss: 0.0038
# Epoch 11/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 12/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0038 - val_loss: 0.0037
# Epoch 13/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 14/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0037 - val_loss: 0.0036
# Epoch 15/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0036 - val_loss: 0.0036
# Epoch 16/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0036 - val_loss: 0.0035
# Epoch 17/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0035 - val_loss: 0.0035
# Epoch 18/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0035 - val_loss: 0.0034
# Epoch 19/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0034 - val_loss: 0.0034
# Epoch 20/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0034 - val_loss: 0.0033
# Epoch 21/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0033 - val_loss: 0.0033
# Epoch 22/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0033 - val_loss: 0.0032
# Epoch 23/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 24/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 25/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 26/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 27/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 28/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0029 - val_loss: 0.0029
# Epoch 29/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0029 - val_loss: 0.0029
# Epoch 30/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0029 - val_loss: 0.0028
# Epoch 31/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 32/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0028 - val_loss: 0.0027
# Epoch 33/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 34/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 35/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 36/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 37/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 38/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 39/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 40/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 41/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 42/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 43/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 44/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 45/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 46/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 47/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 48/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 49/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 50/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 51/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 52/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 53/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 54/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 55/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 56/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 57/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 58/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 59/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 60/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 61/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 62/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 63/300
# 3/3 [==============================] - 7s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 64/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 65/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 66/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 67/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 68/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 69/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 70/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 71/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 72/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 73/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 74/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 75/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 76/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 77/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 78/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 79/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 80/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 81/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 82/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 83/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 84/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 85/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 86/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 87/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 88/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 89/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 90/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 91/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 92/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 93/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 94/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 95/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 96/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 97/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 98/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 99/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 100/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 101/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 102/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 103/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 104/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 105/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 106/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 107/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 108/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 109/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 110/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 111/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 112/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 113/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 114/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 115/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 116/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 117/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 118/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 119/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 120/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 121/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 122/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 123/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 124/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 125/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 126/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 127/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 128/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 129/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 130/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 131/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 132/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 133/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 134/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 135/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 136/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 137/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 138/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 139/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 140/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 141/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 142/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 143/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 144/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 145/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 146/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 147/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 148/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 149/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 150/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 151/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 152/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 153/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 154/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 155/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 156/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 157/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 158/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 159/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 160/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 161/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 162/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 163/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 164/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 165/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 166/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 167/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 168/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 169/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 170/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 171/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 172/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 173/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 174/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 175/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 176/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 177/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 178/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 179/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 180/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 181/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 182/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 183/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 184/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 185/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 186/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 187/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 188/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 189/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 190/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 191/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 192/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 193/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 194/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 195/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 196/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 197/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 198/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 199/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 200/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 201/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 202/300
# 3/3 [==============================] - 7s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 203/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 204/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 205/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 206/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 207/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 208/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 209/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 210/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 211/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 212/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 213/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 214/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 215/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 216/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 217/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 218/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 219/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 220/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 221/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 222/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 223/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 224/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 225/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 226/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 227/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 228/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 229/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 230/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 231/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 232/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 233/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 234/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 235/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 236/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 237/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 238/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 239/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 240/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 241/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 242/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 243/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 244/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 245/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 246/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 247/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 248/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 249/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 250/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 251/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 252/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 253/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 254/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 255/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 256/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 257/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 258/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 259/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 260/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 261/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 262/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 263/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 264/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 265/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 266/300
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 267/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 268/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 269/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 270/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 271/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 272/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 273/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 274/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 275/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 276/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 277/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 278/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 279/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 280/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 281/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 282/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 283/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 284/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 285/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 286/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 287/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 288/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 289/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 290/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 291/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 292/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 293/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 294/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 295/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 296/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 297/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 298/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 299/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 300/300
# 3/3 [==============================] - 5s 2s/step - loss: 0.0024 - val_loss: 0.0024

# %%
if mode == 'train':
     fig1 = plt.figure()
     plt.plot(hist.history['loss'],'r')
     plt.plot(hist.history['val_loss'])

# %%
model.load_weights('vae_cnn')

# Check for validation
for time in range(0,10):
    recoded = model.predict(swe_valid[time:time+1,:,:,:])
    true = preproc.inverse_transform(swe_valid[time:time+1,:,:,:].reshape(1,4096)).reshape(64,64)
    recoded = preproc.inverse_transform(recoded.reshape(1,4096)).reshape(64,64)

    fig, ax = plt.subplots(nrows=1,ncols=2,figsize=(6,6))
    cs1 = ax[0].imshow(true,label='input')
    cs2 = ax[1].imshow(recoded,label='decoded')

    for i in range(2):
        ax[i].set_xlabel('x')
        ax[i].set_ylabel('y')
            
    fig.colorbar(cs1,ax=ax[0],fraction=0.046, pad=0.04)
    fig.colorbar(cs2,ax=ax[1],fraction=0.046, pad=0.04)
    ax[0].set_title(r'True $q_1$')
    ax[1].set_title(r'Reconstructed $q_1$')
    plt.subplots_adjust(wspace=0.5,hspace=-0.3)
    plt.tight_layout()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-224-e4bbb9bb923a> in <module>
#       4 for time in range(0,10):
#       5     recoded = model.predict(swe_valid[time:time+1,:,:,:])
# ----> 6     true = preproc.inverse_transform(swe_valid[time:time+1,:,:,:].reshape(1,4096)).reshape(64,64)
#       7     recoded = preproc.inverse_transform(recoded.reshape(1,4096)).reshape(64,64)
#       8
#
# NameError: name 'preproc' is not defined

# %%
model.load_weights('vae_cnn')

#recoded = model.predict(swe_valid[time:time+1,:,:,:])

# %%
generator = model.predict(swe_valid[0:2])

# %%
print(generator.shape)
# Out:
# (2, 64, 64, 1)

# %%
plt.imshow(generator[1,:,:,0])
plt.figure()
plt.imshow(swe_valid[1,:,:,0])

# %%
encoded_t_arr = K.eval(encoder(swe_train[:,:,:,:].astype('float32')))[0]
encoded_v_arr = K.eval(encoder(swe_valid[:,:,:,:].astype('float32')))[0]
encoded_t = encoded_t_arr
encoded_v = encoded_v_arr



plt.figure()
plt.plot(encoded_t[0:10,0],label='Dimension 1')
plt.plot(encoded_t[0:10,1],label='Dimension 2')
plt.plot(encoded_t[0:10,2],label='Dimension 3')
plt.plot(encoded_t[0:10,3],label='Dimension 4')
plt.legend()
plt.show()

encoded = np.concatenate((encoded_t,encoded_v),axis=0)
np.save('VAE_Coefficient_Training_Data.npy',encoded)
