# %%
import numpy as np
import matplotlib.pylab as plt

# %%
#### FILE PATH ##################
filenumber=5
L = 128   # Dimension of simulation box
path = "./num_" + str(filenumber) + ".npy"   # Path to the input file


#### LOAD DATA #################
data = np.load(path)
img = data[0]       

plt.imshow(img)
plt.figure()
print(img.shape)

stat = img.flatten()
plt.hist(stat, bins = np.arange(120)*0.02) 
plt.title("histogram") 
plt.show()
# Out:
# (128, 128)
